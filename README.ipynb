# %% [markdown]
# # 🎧 Listenerrr – Video Lecture to Study Notes Bot
#
# A multi-modal AI system that auto-generates structured study notes from lecture videos by combining transcription, OCR, and LLM-based summarization.
#
# ---
#
# ## 📌 Project Overview
#
# Students often struggle to take effective notes from long recorded lectures. This tool helps by:
# - Transcribing speech from video (using Whisper)
# - Extracting text from slides (using Tesseract OCR)
# - Generating structured study notes (using Gemini via Google Generative AI)
#
# ---
#
# ## 🛠️ Tech Stack
#
# | Component        | Tool/Library                     |
# |------------------|----------------------------------|
# | Transcription     | `faster-whisper`                |
# | OCR               | `Tesseract OCR`                 |
# | LLM Summarization | `google.generativeai` (Gemini) |
# | Notebook Platform | `Jupyter Notebooks`             |
# | Programming Lang. | Python 3.12                      |
#
# ---
#
# ## 🧪 Project Pipeline
#
# ### 📥 Step 1: Input Collection
# - Upload a `.mp4` or `.mkv` video to `sample_video/`
# - Example: `sample_video/lecture.mp4`
#
# ### 🎙️ Step 2: Transcription
# - Performed using `faster-whisper`
# - Output saved to: `transcripts/whisper_transcript.txt`
# - Notebook: `notebooks/01_transcription.ipynb`
#
# ### 🖼️ Step 3: OCR on Slides
# - Extracted using `Tesseract`
# - Output saved to: `slides_ocr/extracted_slide_text.txt`
# - Notebook: `notebooks/02_ocr.ipynb`
#
# ### 📚 Step 4: Notes Generation
# - Gemini (`google.generativeai`) used for structured summarization
# - Combines cleaned transcript + OCR output
# - Output: `notes/final_notes.md`
# - Notebook: `notebooks/03_notes_generation.ipynb`
#
# ---
